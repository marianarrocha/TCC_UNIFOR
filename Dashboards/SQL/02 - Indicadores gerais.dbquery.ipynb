-- %%
SELECT
    SUM(quantidade_pagamentos) AS total_pagamentos,
    SUM(valor_total) AS valor_total,
    ROUND(AVG(ticket_medio), 2) AS ticket_medio,
    MIN(menor_pagamento) AS menor_pagamento,
    MAX(maior_pagamento) AS maior_pagamento
FROM tcc_unifor.gold.mercado_pago_resumo;
